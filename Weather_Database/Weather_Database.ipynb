# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import linregress
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Turn random longitude and latitude combinations into a list
coordinates = list(lat_lngs)

# %%
#Use citypy to find the closest city to the coordinates and append it to an initiated list called cities
cities =[]
for coordinate in coordinates:
    city= citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 55 == 0 and i >= 55):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = base_url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sabang
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | iqaluit
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | saint-pierre
# Processing Record 8 of Set 1 | baturaja
# Processing Record 9 of Set 1 | sitka
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | geraldton
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 1 | chuy
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | esperance
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | victor harbor
# Processing Record 23 of Set 1 | mar del plata
# Processing Record 24 of Set 1 | ngaoundere
# Processing Record 25 of Set 1 | souillac
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | kavieng
# Processing Record 28 of Set 1 | lenguazaque
# Processing Record 29 of Set 1 | dingle
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | callaway
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | oga
# Processing Record 34 of Set 1 | aban
# Processing Record 35 of Set 1 | hithadhoo
# Processing Record 36 of Set 1 | narsaq
# Processing Record 37 of Set 1 | ribeira grande
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | mount isa
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | ulladulla
# Processing Record 42 of Set 1 | kolyvan
# Processing Record 43 of Set 1 | saldanha
# Processing Record 44 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | vigrestad
# Processing Record 47 of Set 1 | tuma
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | barrow
# Processing Record 50 of Set 1 | yumen
# Processing Record 51 of Set 1 | roald
# Processing Record 52 of Set 1 | nanortalik
# Processing Record 53 of Set 1 | atuona
# Processing Record 54 of Set 1 | castro
# Processing Record 55 of Set 1 | tiksi
# Processing Record 1 of Set 2 | vaini
# Processing Record 2 of Set 2 | bako
# Processing Record 3 of Set 2 | aklavik
# Processing Record 4 of Set 2 | port keats
# Processing Record 5 of Set 2 | cidreira
# Processing Record 6 of Set 2 | fairmont
# Processing Record 7 of Set 2 | deputatskiy
# Processing Record 8 of Set 2 | vanino
# Processing Record 9 of Set 2 | segovia
# Processing Record 10 of Set 2 | tilichiki
# Processing Record 11 of Set 2 | port lincoln
# Processing Record 12 of Set 2 | khatanga
# Processing Record 13 of Set 2 | bluefields
# Processing Record 14 of Set 2 | lavrentiya
# Processing Record 15 of Set 2 | tasiilaq
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 2 | soledade
# Processing Record 19 of Set 2 | vitim
# Processing Record 20 of Set 2 | santa rosa
# Processing Record 21 of Set 2 | pangnirtung
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | baykit
# Processing Record 24 of Set 2 | georgetown
# Processing Record 25 of Set 2 | hofn
# Processing Record 26 of Set 2 | avarua
# Processing Record 27 of Set 2 | bom jesus
# Processing Record 28 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 2 | namanga
# Processing Record 30 of Set 2 | regeneracao
# Processing Record 31 of Set 2 | busselton
# Processing Record 32 of Set 2 | luderitz
# Processing Record 33 of Set 2 | sampit
# Processing Record 34 of Set 2 | bethel
# Processing Record 35 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 2 | sandwick
# Processing Record 37 of Set 2 | honiara
# Processing Record 38 of Set 2 | zhuhai
# Processing Record 39 of Set 2 | rawson
# Processing Record 40 of Set 2 | eyl
# Processing Record 41 of Set 2 | kaitangata
# Processing Record 42 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 2 | lethem
# Processing Record 44 of Set 2 | port alfred
# Processing Record 45 of Set 2 | oranjemund
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | sept-iles
# Processing Record 48 of Set 2 | cayenne
# Processing Record 49 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 2 | saskylakh
# Processing Record 51 of Set 2 | hasaki
# Processing Record 52 of Set 2 | lorengau
# Processing Record 53 of Set 2 | banda aceh
# Processing Record 54 of Set 2 | nantucket
# Processing Record 55 of Set 2 | kayes
# Processing Record 1 of Set 3 | dukat
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | ancud
# Processing Record 4 of Set 3 | alofi
# Processing Record 5 of Set 3 | treuchtlingen
# Processing Record 6 of Set 3 | shingu
# Processing Record 7 of Set 3 | carnarvon
# Processing Record 8 of Set 3 | namibe
# Processing Record 9 of Set 3 | cabo san lucas
# Processing Record 10 of Set 3 | mandal
# Processing Record 11 of Set 3 | ukiah
# Processing Record 12 of Set 3 | akyab
# Processing Record 13 of Set 3 | east london
# Processing Record 14 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 15 of Set 3 | longyearbyen
# Processing Record 16 of Set 3 | sibolga
# Processing Record 17 of Set 3 | okhotsk
# Processing Record 18 of Set 3 | victoria
# Processing Record 19 of Set 3 | gorontalo
# Processing Record 20 of Set 3 | vardo
# Processing Record 21 of Set 3 | cape town
# Processing Record 22 of Set 3 | banjar
# Processing Record 23 of Set 3 | mahebourg
# Processing Record 24 of Set 3 | upernavik
# Processing Record 25 of Set 3 | katsuura
# Processing Record 26 of Set 3 | cozumel
# Processing Record 27 of Set 3 | provideniya
# Processing Record 28 of Set 3 | bengkulu
# Processing Record 29 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 3 | bathsheba
# Processing Record 31 of Set 3 | komsomolskiy
# Processing Record 32 of Set 3 | torbay
# Processing Record 33 of Set 3 | qaqortoq
# Processing Record 34 of Set 3 | lompoc
# Processing Record 35 of Set 3 | chokurdakh
# Processing Record 36 of Set 3 | lianzhou
# Processing Record 37 of Set 3 | tura
# Processing Record 38 of Set 3 | pevek
# Processing Record 39 of Set 3 | denison
# Processing Record 40 of Set 3 | bambous virieux
# Processing Record 41 of Set 3 | vila
# Processing Record 42 of Set 3 | touros
# Processing Record 43 of Set 3 | kostomuksha
# Processing Record 44 of Set 3 | salalah
# Processing Record 45 of Set 3 | maxixe
# Processing Record 46 of Set 3 | naze
# Processing Record 47 of Set 3 | rafaela
# Processing Record 48 of Set 3 | bilibino
# Processing Record 49 of Set 3 | husavik
# Processing Record 50 of Set 3 | kamaishi
# Processing Record 51 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 52 of Set 3 | yuancheng
# Processing Record 53 of Set 3 | sola
# Processing Record 54 of Set 3 | male
# Processing Record 55 of Set 3 | la libertad
# Processing Record 1 of Set 4 | prattville
# Processing Record 2 of Set 4 | petropavlovka
# Processing Record 3 of Set 4 | ikongo
# Processing Record 4 of Set 4 | bara
# Processing Record 5 of Set 4 | port elizabeth
# Processing Record 6 of Set 4 | la ronge
# Processing Record 7 of Set 4 | kapaa
# Processing Record 8 of Set 4 | muana
# Processing Record 9 of Set 4 | ilulissat
# Processing Record 10 of Set 4 | lere
# Processing Record 11 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 12 of Set 4 | san policarpo
# Processing Record 13 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 4 | boatlaname
# City not found. Skipping...
# Processing Record 15 of Set 4 | rolim de moura
# City not found. Skipping...
# Processing Record 16 of Set 4 | el alto
# Processing Record 17 of Set 4 | mombetsu
# Processing Record 18 of Set 4 | mount gambier
# Processing Record 19 of Set 4 | walvis bay
# Processing Record 20 of Set 4 | aktau
# Processing Record 21 of Set 4 | parrita
# Processing Record 22 of Set 4 | hovd
# Processing Record 23 of Set 4 | vanavara
# Processing Record 24 of Set 4 | inirida
# Processing Record 25 of Set 4 | basoko
# Processing Record 26 of Set 4 | san patricio
# Processing Record 27 of Set 4 | yerbogachen
# Processing Record 28 of Set 4 | kahului
# Processing Record 29 of Set 4 | westport
# Processing Record 30 of Set 4 | sorong
# Processing Record 31 of Set 4 | zacatecoluca
# Processing Record 32 of Set 4 | puerto ayora
# Processing Record 33 of Set 4 | kant
# Processing Record 34 of Set 4 | sijunjung
# Processing Record 35 of Set 4 | dayong
# Processing Record 36 of Set 4 | pasighat
# Processing Record 37 of Set 4 | meiganga
# Processing Record 38 of Set 4 | noumea
# Processing Record 39 of Set 4 | west wendover
# Processing Record 40 of Set 4 | netivot
# Processing Record 41 of Set 4 | klaksvik
# Processing Record 42 of Set 4 | itoman
# Processing Record 43 of Set 4 | hamina
# Processing Record 44 of Set 4 | markova
# Processing Record 45 of Set 4 | normandin
# Processing Record 46 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 4 | vila franca do campo
# Processing Record 48 of Set 4 | clearwater
# Processing Record 49 of Set 4 | hamilton
# Processing Record 50 of Set 4 | kazerun
# Processing Record 51 of Set 4 | sheridan
# Processing Record 52 of Set 4 | grants pass
# Processing Record 53 of Set 4 | santiago de cao
# Processing Record 54 of Set 4 | ust-koksa
# Processing Record 55 of Set 4 | ust-tsilma
# Processing Record 1 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 5 | hambantota
# Processing Record 4 of Set 5 | mogadishu
# Processing Record 5 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 6 of Set 5 | kichera
# Processing Record 7 of Set 5 | lata
# Processing Record 8 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 5 | pemba
# Processing Record 10 of Set 5 | ust-kuyga
# Processing Record 11 of Set 5 | paramonga
# Processing Record 12 of Set 5 | afgoye
# City not found. Skipping...
# Processing Record 13 of Set 5 | riyadh
# Processing Record 14 of Set 5 | srednekolymsk
# Processing Record 15 of Set 5 | lebu
# Processing Record 16 of Set 5 | phuntsholing
# Processing Record 17 of Set 5 | samana
# Processing Record 18 of Set 5 | doha
# Processing Record 19 of Set 5 | arraial do cabo
# Processing Record 20 of Set 5 | pacatuba
# Processing Record 21 of Set 5 | makakilo city
# Processing Record 22 of Set 5 | goundi
# Processing Record 23 of Set 5 | chernyshevskiy
# Processing Record 24 of Set 5 | mapiri
# Processing Record 25 of Set 5 | kruisfontein
# Processing Record 26 of Set 5 | san alberto
# Processing Record 27 of Set 5 | barra do garcas
# Processing Record 28 of Set 5 | petersburg
# Processing Record 29 of Set 5 | kodiak
# Processing Record 30 of Set 5 | katherine
# Processing Record 31 of Set 5 | havelock
# Processing Record 32 of Set 5 | beihai
# Processing Record 33 of Set 5 | constitucion
# Processing Record 34 of Set 5 | bonavista
# Processing Record 35 of Set 5 | dorfen
# Processing Record 36 of Set 5 | barcelos
# Processing Record 37 of Set 5 | ahipara
# Processing Record 38 of Set 5 | huangnihe
# Processing Record 39 of Set 5 | wanning
# Processing Record 40 of Set 5 | kidal
# Processing Record 41 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 5 | zhigansk
# Processing Record 43 of Set 5 | greymouth
# Processing Record 44 of Set 5 | mackenzie
# Processing Record 45 of Set 5 | santarem
# Processing Record 46 of Set 5 | lubango
# Processing Record 47 of Set 5 | leningradskiy
# Processing Record 48 of Set 5 | tromso
# Processing Record 49 of Set 5 | uvat
# Processing Record 50 of Set 5 | port blair
# Processing Record 51 of Set 5 | armacao dos buzios
# City not found. Skipping...
# Processing Record 52 of Set 5 | high level
# Processing Record 53 of Set 5 | luganville
# Processing Record 54 of Set 5 | baherden
# Processing Record 55 of Set 5 | sarangani
# Processing Record 1 of Set 6 | magadi
# Processing Record 2 of Set 6 | svetlogorsk
# Processing Record 3 of Set 6 | caravelas
# Processing Record 4 of Set 6 | quatre cocos
# Processing Record 5 of Set 6 | san luis
# Processing Record 6 of Set 6 | oktyabrskiy
# Processing Record 7 of Set 6 | clyde river
# Processing Record 8 of Set 6 | fortuna
# Processing Record 9 of Set 6 | acajutla
# Processing Record 10 of Set 6 | vostok
# Processing Record 11 of Set 6 | saint george
# Processing Record 12 of Set 6 | codrington
# Processing Record 13 of Set 6 | hangzhou
# Processing Record 14 of Set 6 | yulara
# Processing Record 15 of Set 6 | jiroft
# City not found. Skipping...
# Processing Record 16 of Set 6 | skibbereen
# Processing Record 17 of Set 6 | isangel
# Processing Record 18 of Set 6 | sibu
# Processing Record 19 of Set 6 | sao joao da barra
# Processing Record 20 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 21 of Set 6 | troitskoye
# Processing Record 22 of Set 6 | tual
# Processing Record 23 of Set 6 | alyangula
# Processing Record 24 of Set 6 | san pedro
# Processing Record 25 of Set 6 | sioux lookout
# Processing Record 26 of Set 6 | salamiyah
# Processing Record 27 of Set 6 | amalapuram
# Processing Record 28 of Set 6 | saint-joseph
# Processing Record 29 of Set 6 | cherskiy
# Processing Record 30 of Set 6 | adelaide
# Processing Record 31 of Set 6 | ajaccio
# Processing Record 32 of Set 6 | nkowakowa
# Processing Record 33 of Set 6 | south lake tahoe
# Processing Record 34 of Set 6 | ostrovnoy
# Processing Record 35 of Set 6 | sturgeon bay
# Processing Record 36 of Set 6 | puerto carreno
# Processing Record 37 of Set 6 | mayumba
# Processing Record 38 of Set 6 | shetpe
# Processing Record 39 of Set 6 | khandyga
# Processing Record 40 of Set 6 | zyryanka
# Processing Record 41 of Set 6 | turukhansk
# Processing Record 42 of Set 6 | mana
# Processing Record 43 of Set 6 | tibana
# Processing Record 44 of Set 6 | lasa
# Processing Record 45 of Set 6 | sibiti
# Processing Record 46 of Set 6 | dwarka
# Processing Record 47 of Set 6 | high rock
# Processing Record 48 of Set 6 | port hardy
# Processing Record 49 of Set 6 | marawi
# Processing Record 50 of Set 6 | pisco
# Processing Record 51 of Set 6 | barra da estiva
# Processing Record 52 of Set 6 | sao filipe
# Processing Record 53 of Set 6 | lutz
# Processing Record 54 of Set 6 | harper
# Processing Record 55 of Set 6 | faanui
# Processing Record 1 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 2 of Set 7 | norman wells
# Processing Record 3 of Set 7 | maldonado
# Processing Record 4 of Set 7 | guerrero negro
# Processing Record 5 of Set 7 | te anau
# Processing Record 6 of Set 7 | maghama
# City not found. Skipping...
# Processing Record 7 of Set 7 | shirpur
# Processing Record 8 of Set 7 | kodinsk
# Processing Record 9 of Set 7 | puerto rico
# Processing Record 10 of Set 7 | rudnaya pristan
# Processing Record 11 of Set 7 | mount vernon
# Processing Record 12 of Set 7 | severo-kurilsk
# Processing Record 13 of Set 7 | robore
# Processing Record 14 of Set 7 | amlame
# Processing Record 15 of Set 7 | adrar
# Processing Record 16 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 7 | skjervoy
# Processing Record 18 of Set 7 | lipari
# Processing Record 19 of Set 7 | launceston
# Processing Record 20 of Set 7 | adet
# Processing Record 21 of Set 7 | saquena
# Processing Record 22 of Set 7 | matara
# Processing Record 23 of Set 7 | xingyi
# Processing Record 24 of Set 7 | bubaque
# Processing Record 25 of Set 7 | hillsboro
# Processing Record 26 of Set 7 | fairbanks
# Processing Record 27 of Set 7 | abu samrah
# Processing Record 28 of Set 7 | ixtapa
# Processing Record 29 of Set 7 | marrakesh
# Processing Record 30 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 31 of Set 7 | tabou
# Processing Record 32 of Set 7 | turbat
# Processing Record 33 of Set 7 | comodoro rivadavia
# Processing Record 34 of Set 7 | margate
# Processing Record 35 of Set 7 | fryanovo
# Processing Record 36 of Set 7 | qasigiannguit
# Processing Record 37 of Set 7 | egvekinot
# Processing Record 38 of Set 7 | makariv
# Processing Record 39 of Set 7 | jiazi
# Processing Record 40 of Set 7 | narok
# Processing Record 41 of Set 7 | middelburg
# Processing Record 42 of Set 7 | aden
# Processing Record 43 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 7 | parnarama
# Processing Record 45 of Set 7 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 46 of Set 7 | havre-saint-pierre
# Processing Record 47 of Set 7 | virginia beach
# Processing Record 48 of Set 7 | stolin
# Processing Record 49 of Set 7 | byron bay
# Processing Record 50 of Set 7 | ulaanbaatar
# Processing Record 51 of Set 7 | sinnamary
# Processing Record 52 of Set 7 | dunedin
# Processing Record 53 of Set 7 | labuhan
# Processing Record 54 of Set 7 | henties bay
# Processing Record 55 of Set 7 | abu kamal
# Processing Record 1 of Set 8 | puga
# Processing Record 2 of Set 8 | salinopolis
# Processing Record 3 of Set 8 | itacarambi
# Processing Record 4 of Set 8 | arkhangelsk
# Processing Record 5 of Set 8 | nelson bay
# Processing Record 6 of Set 8 | kununurra
# Processing Record 7 of Set 8 | morondava
# Processing Record 8 of Set 8 | vikhorevka
# Processing Record 9 of Set 8 | amli
# Processing Record 10 of Set 8 | sisimiut
# Processing Record 11 of Set 8 | plettenberg bay
# Processing Record 12 of Set 8 | vestmannaeyjar
# Processing Record 13 of Set 8 | lyubim
# Processing Record 14 of Set 8 | kutum
# Processing Record 15 of Set 8 | washington
# Processing Record 16 of Set 8 | carndonagh
# Processing Record 17 of Set 8 | ahuimanu
# Processing Record 18 of Set 8 | domoni
# Processing Record 19 of Set 8 | ponta do sol
# Processing Record 20 of Set 8 | haines junction
# Processing Record 21 of Set 8 | manicore
# Processing Record 22 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 8 | wenling
# Processing Record 24 of Set 8 | faya
# Processing Record 25 of Set 8 | nuuk
# Processing Record 26 of Set 8 | kirakira
# Processing Record 27 of Set 8 | port moresby
# Processing Record 28 of Set 8 | ahumada
# City not found. Skipping...
# Processing Record 29 of Set 8 | bereda
# Processing Record 30 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 8 | airai
# Processing Record 32 of Set 8 | ponta delgada
# Processing Record 33 of Set 8 | chapais
# Processing Record 34 of Set 8 | yar-sale
# Processing Record 35 of Set 8 | hecun
# Processing Record 36 of Set 8 | tezu
# Processing Record 37 of Set 8 | sayyan
# Processing Record 38 of Set 8 | tautira
# Processing Record 39 of Set 8 | egyek
# Processing Record 40 of Set 8 | bandarbeyla
# Processing Record 41 of Set 8 | gorom-gorom
# Processing Record 42 of Set 8 | stykkisholmur
# Processing Record 43 of Set 8 | erzin
# Processing Record 44 of Set 8 | olinda
# Processing Record 45 of Set 8 | dillon
# Processing Record 46 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 8 | grindavik
# Processing Record 48 of Set 8 | jalu
# Processing Record 49 of Set 8 | mayskiy
# Processing Record 50 of Set 8 | chagoda
# Processing Record 51 of Set 8 | pacific grove
# Processing Record 52 of Set 8 | kedrovyy
# Processing Record 53 of Set 8 | ucluelet
# Processing Record 54 of Set 8 | college
# Processing Record 55 of Set 8 | sainte-claire
# Processing Record 1 of Set 9 | xichang
# Processing Record 2 of Set 9 | waipawa
# Processing Record 3 of Set 9 | aykhal
# Processing Record 4 of Set 9 | popondetta
# Processing Record 5 of Set 9 | kinablangan
# Processing Record 6 of Set 9 | metro
# Processing Record 7 of Set 9 | riviere-au-renard
# Processing Record 8 of Set 9 | ardistan
# City not found. Skipping...
# Processing Record 9 of Set 9 | hearst
# Processing Record 10 of Set 9 | pshekhskaya
# Processing Record 11 of Set 9 | ako
# Processing Record 12 of Set 9 | broome
# Processing Record 13 of Set 9 | talas
# Processing Record 14 of Set 9 | beyneu
# Processing Record 15 of Set 9 | sault sainte marie
# Processing Record 16 of Set 9 | burnie
# Processing Record 17 of Set 9 | jibuti
# Processing Record 18 of Set 9 | russell
# Processing Record 19 of Set 9 | mayo
# Processing Record 20 of Set 9 | kargat
# Processing Record 21 of Set 9 | berdigestyakh
# Processing Record 22 of Set 9 | pontianak
# Processing Record 23 of Set 9 | falam
# Processing Record 24 of Set 9 | nouadhibou
# Processing Record 25 of Set 9 | lyngseidet
# Processing Record 26 of Set 9 | preston
# Processing Record 27 of Set 9 | rio grande
# Processing Record 28 of Set 9 | vondrozo
# Processing Record 29 of Set 9 | los llanos de aridane
# Processing Record 30 of Set 9 | teya
# Processing Record 31 of Set 9 | morro bay
# Processing Record 32 of Set 9 | hede
# Processing Record 33 of Set 9 | nabire
# Processing Record 34 of Set 9 | santa isabel do rio negro
# Processing Record 35 of Set 9 | aquidaba
# Processing Record 36 of Set 9 | goderich
# Processing Record 37 of Set 9 | ambon
# Processing Record 38 of Set 9 | grand gaube
# Processing Record 39 of Set 9 | uruzgan
# Processing Record 40 of Set 9 | camargo
# Processing Record 41 of Set 9 | malindi
# Processing Record 42 of Set 9 | khandbari
# Processing Record 43 of Set 9 | nome
# Processing Record 44 of Set 9 | gusau
# Processing Record 45 of Set 9 | melong
# Processing Record 46 of Set 9 | bilma
# Processing Record 47 of Set 9 | christchurch
# Processing Record 48 of Set 9 | catamarca
# Processing Record 49 of Set 9 | campos belos
# Processing Record 50 of Set 9 | nauta
# Processing Record 51 of Set 9 | negombo
# Processing Record 52 of Set 9 | tombouctou
# Processing Record 53 of Set 9 | daokou
# Processing Record 54 of Set 9 | montepuez
# Processing Record 55 of Set 9 | szamotuly
# Processing Record 1 of Set 10 | general roca
# Processing Record 2 of Set 10 | iskateley
# Processing Record 3 of Set 10 | setermoen
# Processing Record 4 of Set 10 | santiago del estero
# Processing Record 5 of Set 10 | kenora
# Processing Record 6 of Set 10 | xining
# Processing Record 7 of Set 10 | nanded
# City not found. Skipping...
# Processing Record 8 of Set 10 | port augusta
# Processing Record 9 of Set 10 | trenggalek
# Processing Record 10 of Set 10 | baker city
# Processing Record 11 of Set 10 | liverpool
# Processing Record 12 of Set 10 | beloha
# Processing Record 13 of Set 10 | inhambane
# Processing Record 14 of Set 10 | aksu
# Processing Record 15 of Set 10 | mayari
# City not found. Skipping...
# Processing Record 16 of Set 10 | ilam
# Processing Record 17 of Set 10 | forquilhinha
# Processing Record 18 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 10 | sibulan
# Processing Record 20 of Set 10 | aldan
# Processing Record 21 of Set 10 | sorland
# Processing Record 22 of Set 10 | fortuna foothills
# Processing Record 23 of Set 10 | bedesa
# Processing Record 24 of Set 10 | tigil
# Processing Record 25 of Set 10 | kumo
# Processing Record 26 of Set 10 | ban nahin
# Processing Record 27 of Set 10 | ambilobe
# Processing Record 28 of Set 10 | krasnoselkup
# Processing Record 29 of Set 10 | vao
# Processing Record 30 of Set 10 | ushirombo
# Processing Record 31 of Set 10 | boa vista
# Processing Record 32 of Set 10 | tsiroanomandidy
# Processing Record 33 of Set 10 | krasnyy yar
# Processing Record 34 of Set 10 | saint anthony
# Processing Record 35 of Set 10 | ust-maya
# Processing Record 36 of Set 10 | miandrivazo
# Processing Record 37 of Set 10 | palia kalan
# Processing Record 38 of Set 10 | kamina
# Processing Record 39 of Set 10 | katima mulilo
# Processing Record 40 of Set 10 | hualmay
# Processing Record 41 of Set 10 | grand-santi
# Processing Record 42 of Set 10 | anloga
# Processing Record 43 of Set 10 | zaraza
# Processing Record 44 of Set 10 | chhapar
# Processing Record 45 of Set 10 | tuysarkan
# City not found. Skipping...
# Processing Record 46 of Set 10 | ushibuka
# Processing Record 47 of Set 10 | brokopondo
# Processing Record 48 of Set 10 | florianopolis
# Processing Record 49 of Set 10 | lushunkou
# City not found. Skipping...
# Processing Record 50 of Set 10 | tokur
# Processing Record 51 of Set 10 | acarau
# Processing Record 52 of Set 10 | kinston
# Processing Record 53 of Set 10 | tshela
# Processing Record 54 of Set 10 | dekar
# Processing Record 55 of Set 10 | evensk
# Processing Record 1 of Set 11 | ginir
# Processing Record 2 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 11 | vila velha
# Processing Record 4 of Set 11 | corning
# Processing Record 5 of Set 11 | erenhot
# Processing Record 6 of Set 11 | merrillville
# Processing Record 7 of Set 11 | obregon
# Processing Record 8 of Set 11 | iquique
# Processing Record 9 of Set 11 | bukachacha
# Processing Record 10 of Set 11 | santa maria
# Processing Record 11 of Set 11 | beringovskiy
# Processing Record 12 of Set 11 | igrim
# Processing Record 13 of Set 11 | paamiut
# Processing Record 14 of Set 11 | bagdarin
# Processing Record 15 of Set 11 | auki
# Processing Record 16 of Set 11 | chernihiv
# Processing Record 17 of Set 11 | kingsport
# Processing Record 18 of Set 11 | kiruna
# Processing Record 19 of Set 11 | taksimo
# Processing Record 20 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 21 of Set 11 | marau
# Processing Record 22 of Set 11 | huarmey
# Processing Record 23 of Set 11 | tadine
# Processing Record 24 of Set 11 | darhan
# Processing Record 25 of Set 11 | verkhnevilyuysk
# Processing Record 26 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 28 of Set 11 | richards bay
# Processing Record 29 of Set 11 | kiunga
# Processing Record 30 of Set 11 | rio gallegos
# Processing Record 31 of Set 11 | manokwari
# Processing Record 32 of Set 11 | talnakh
# Processing Record 33 of Set 11 | tuatapere
# Processing Record 34 of Set 11 | tari
# Processing Record 35 of Set 11 | jinxiang
# Processing Record 36 of Set 11 | biltine
# Processing Record 37 of Set 11 | oriximina
# Processing Record 38 of Set 11 | charters towers
# Processing Record 39 of Set 11 | sistranda
# Processing Record 40 of Set 11 | manacapuru
# Processing Record 41 of Set 11 | araouane
# Processing Record 42 of Set 11 | miracatu
# Processing Record 43 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 11 | ayagoz
# Processing Record 45 of Set 11 | phon thong
# Processing Record 46 of Set 11 | minab
# Processing Record 47 of Set 11 | wladyslawowo
# Processing Record 48 of Set 11 | baksan
# Processing Record 49 of Set 11 | madaoua
# Processing Record 50 of Set 11 | flinders
# Processing Record 51 of Set 11 | voyvozh
# Processing Record 52 of Set 11 | odesskoye
# Processing Record 53 of Set 11 | havre
# Processing Record 54 of Set 11 | talcher
# Processing Record 55 of Set 11 | guiglo
# Processing Record 1 of Set 12 | necochea
# Processing Record 2 of Set 12 | sao gabriel da cachoeira
# Processing Record 3 of Set 12 | lucea
# Processing Record 4 of Set 12 | fomboni
# Processing Record 5 of Set 12 | laguna
# Processing Record 6 of Set 12 | dire dawa
# Processing Record 7 of Set 12 | nchelenge
# Processing Record 8 of Set 12 | nemuro
# Processing Record 9 of Set 12 | colchester
# Processing Record 10 of Set 12 | san carlos de bariloche
# Processing Record 11 of Set 12 | nykobing
# City not found. Skipping...
# Processing Record 12 of Set 12 | sabha
# Processing Record 13 of Set 12 | paka
# Processing Record 14 of Set 12 | rodez
# Processing Record 15 of Set 12 | bintulu
# Processing Record 16 of Set 12 | benesat
# Processing Record 17 of Set 12 | kota tinggi
# Processing Record 18 of Set 12 | acapulco
# Processing Record 19 of Set 12 | mogzon
# Processing Record 20 of Set 12 | camacha
# Processing Record 21 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 22 of Set 12 | elizabeth city
# Processing Record 23 of Set 12 | meadow lake
# Processing Record 24 of Set 12 | visby
# Processing Record 25 of Set 12 | yemtsa
# Processing Record 26 of Set 12 | alice springs
# Processing Record 27 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 28 of Set 12 | sungai petani
# Processing Record 29 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 30 of Set 12 | kudahuvadhoo
# Processing Record 31 of Set 12 | ontario
# Processing Record 32 of Set 12 | tara
# Processing Record 33 of Set 12 | kuandian
# Processing Record 34 of Set 12 | iwanai
# Processing Record 35 of Set 12 | kosovo polje
# Processing Record 36 of Set 12 | kenai
# Processing Record 37 of Set 12 | kholodnyy
# Processing Record 38 of Set 12 | asfi
# Processing Record 39 of Set 12 | hobyo
# Processing Record 40 of Set 12 | bireun
# Processing Record 41 of Set 12 | mudgee
# Processing Record 42 of Set 12 | lagoa
# Processing Record 43 of Set 12 | nieuwpoort
# Processing Record 44 of Set 12 | juneau
# Processing Record 45 of Set 12 | sri aman
# Processing Record 46 of Set 12 | bombay
# Processing Record 47 of Set 12 | najran
# Processing Record 48 of Set 12 | whitehorse
# Processing Record 49 of Set 12 | mandalgovi
# Processing Record 50 of Set 12 | champa
# Processing Record 51 of Set 12 | vanderhoof
# Processing Record 52 of Set 12 | boromo
# Processing Record 53 of Set 12 | campina grande do sul
# Processing Record 54 of Set 12 | megion
# Processing Record 55 of Set 12 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 1 of Set 13 | dmytrivka
# Processing Record 2 of Set 13 | robertson
# Processing Record 3 of Set 13 | minbu
# Processing Record 4 of Set 13 | sidi bu zayd
# City not found. Skipping...
# Processing Record 5 of Set 13 | omboue
# Processing Record 6 of Set 13 | lahaina
# Processing Record 7 of Set 13 | okato
# Processing Record 8 of Set 13 | suihua
# Processing Record 9 of Set 13 | maryville
# Processing Record 10 of Set 13 | hervey bay
# Processing Record 11 of Set 13 | chernukha
# Processing Record 12 of Set 13 | benjamin hill
# Processing Record 13 of Set 13 | abha
# Processing Record 14 of Set 13 | rupert
# Processing Record 15 of Set 13 | turayf
# Processing Record 16 of Set 13 | inuvik
# Processing Record 17 of Set 13 | myaundzha
# Processing Record 18 of Set 13 | axim
# Processing Record 19 of Set 13 | okha
# Processing Record 20 of Set 13 | valdivia
# Processing Record 21 of Set 13 | arman
# Processing Record 22 of Set 13 | kalinovskoye
# Processing Record 23 of Set 13 | viedma
# Processing Record 24 of Set 13 | shasta lake
# Processing Record 25 of Set 13 | boo
# Processing Record 26 of Set 13 | shubarkuduk
# Processing Record 27 of Set 13 | tazovskiy
# Processing Record 28 of Set 13 | sakakah
# Processing Record 29 of Set 13 | coihaique
# Processing Record 30 of Set 13 | vangaindrano
# Processing Record 31 of Set 13 | vertou
# Processing Record 32 of Set 13 | catalao
# Processing Record 33 of Set 13 | torit
# Processing Record 34 of Set 13 | el paso
# Processing Record 35 of Set 13 | ust-karsk
# Processing Record 36 of Set 13 | nagato
# Processing Record 37 of Set 13 | camacupa
# Processing Record 38 of Set 13 | mingguang
# Processing Record 39 of Set 13 | poum
# Processing Record 40 of Set 13 | ketchikan
# Processing Record 41 of Set 13 | guhagar
# Processing Record 42 of Set 13 | kaeo
# Processing Record 43 of Set 13 | carlisle
# Processing Record 44 of Set 13 | tibati
# Processing Record 45 of Set 13 | saint-georges
# Processing Record 46 of Set 13 | sobolevo
# Processing Record 47 of Set 13 | kembolcha
# Processing Record 48 of Set 13 | buchanan
# Processing Record 49 of Set 13 | anuchino
# Processing Record 50 of Set 13 | mikumi
# Processing Record 51 of Set 13 | kolokani
# Processing Record 52 of Set 13 | hirara
# Processing Record 53 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 54 of Set 13 | baijiantan
# Processing Record 55 of Set 13 | bontang
# Processing Record 1 of Set 14 | borovoy
# Processing Record 2 of Set 14 | shahpur
# Processing Record 3 of Set 14 | mercedes
# Processing Record 4 of Set 14 | moissala
# Processing Record 5 of Set 14 | obsharovka
# Processing Record 6 of Set 14 | chunan
# Processing Record 7 of Set 14 | rocha
# Processing Record 8 of Set 14 | pag
# Processing Record 9 of Set 14 | korla
# Processing Record 10 of Set 14 | eirunepe
# Processing Record 11 of Set 14 | morristown
# Processing Record 12 of Set 14 | nioro
# Processing Record 13 of Set 14 | can
# Processing Record 14 of Set 14 | biak
# Processing Record 15 of Set 14 | bud
# Processing Record 16 of Set 14 | sindor
# Processing Record 17 of Set 14 | horsham
# Processing Record 18 of Set 14 | hay river
# Processing Record 19 of Set 14 | fort walton beach
# Processing Record 20 of Set 14 | domazlice
# Processing Record 21 of Set 14 | solsvik
# City not found. Skipping...
# Processing Record 22 of Set 14 | ojinaga
# Processing Record 23 of Set 14 | santa cecilia
# Processing Record 24 of Set 14 | pierre
# Processing Record 25 of Set 14 | neuquen
# Processing Record 26 of Set 14 | lujan
# Processing Record 27 of Set 14 | mildura
# Processing Record 28 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 14 | calbuco
# Processing Record 30 of Set 14 | bahir dar
# Processing Record 31 of Set 14 | tucuru
# Processing Record 32 of Set 14 | fredericksburg
# Processing Record 33 of Set 14 | horve
# Processing Record 34 of Set 14 | moerai
# Processing Record 35 of Set 14 | teguise
# Processing Record 36 of Set 14 | kantunilkin
# Processing Record 37 of Set 14 | pundaguitan
# Processing Record 38 of Set 14 | maua
# Processing Record 39 of Set 14 | krasnyye tkachi
# Processing Record 40 of Set 14 | xuddur
# Processing Record 41 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 14 | prince albert
# Processing Record 43 of Set 14 | williams lake
# Processing Record 44 of Set 14 | syracuse
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert City Data into DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Sabang      ID   5.8933   95.3214     82.47        74          46
# 1   Yellowknife      CA  62.4560 -114.3525     14.29        63         100
# 2       Iqaluit      CA  63.7506  -68.5145     -5.31        70          18
# 3       Ushuaia      AR -54.8000  -68.3000     45.88        77         100
# 4  Saint-Pierre      RE -21.3393   55.4781     78.48        91           0
# 5      Baturaja      ID  -4.1333  104.1667     72.14        94          92
# 6         Sitka      US  57.0531 -135.3300     46.29        57         100
# 7    Nikolskoye      RU  59.7035   30.7861     35.49        86           2
# 8      Hermanus      ZA -34.4187   19.2345     71.80        82          84
# 9       Mataura      NZ -46.1927  168.8643     61.47        79           5
#
#    Wind Speed Current Description
# 0       11.18    scattered clouds
# 1        5.99     overcast clouds
# 2       15.99          few clouds
# 3        3.85          light rain
# 4        4.61           clear sky
# 5        2.15     overcast clouds
# 6       19.57     overcast clouds
# 7        5.06           clear sky
# 8       15.01       broken clouds
# 9        1.28           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
